# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import nltk
import tensorflow
import os

# %%
#pip install nltk - 'Timestamp','Type','Info','ID','Hashcode','Transaction,Transaction_1','No.1','No.2','Customer_ID',
                                                                          'Q_ID',

# %%
data = pd.read_table('pwLog_2022-06-19T1-58-38-888.log', header=None,names=['Date','Message'],sep=' ')
data
# Out:
#                                                                                                                                               Date  \
# 2022-06-21 15:07:50,991 EXTERNAL INFO  ID42062 xkKUwW5GV5kKhtiVQJx2zxyxhVveZUlCjjWx-Imy_d0c40a... 1655842070390 321646101 1 1 NO_CUSTOMER_ID   NaN
#            15:07:50,994 EXTERNAL INFO  ID42062 xkKUwW5GV5kKhtiVQJx2zxyxhVveZUlCjjWx-Imy_d0c40a... 1655842070390 321646101 1 1 NO_CUSTOMER_ID   NaN
#                                                                                                                               NO_CUSTOMER_ID   NaN
#                                                                                                                               NO_CUSTOMER_ID   NaN
#                                                                                                                               NO_CUSTOMER_ID   NaN
# ...

# %%
data['Date']
# Out:
# 2022-06-21  15:07:50,991  EXTERNAL  INFO   ID42062  xkKUwW5GV5kKhtiVQJx2zxyxhVveZUlCjjWx-Imy_d0c40a1d-8e20-474e-8b9f-ca9fc736ebcd  1655842070390  321646101  1  1  NO_CUSTOMER_ID   NaN
#             15:07:50,994  EXTERNAL  INFO   ID42062  xkKUwW5GV5kKhtiVQJx2zxyxhVveZUlCjjWx-Imy_d0c40a1d-8e20-474e-8b9f-ca9fc736ebcd  1655842070390  321646101  1  1  NO_CUSTOMER_ID   NaN
#                                                                                                                                                                    NO_CUSTOMER_ID   NaN
#                                                                                                                                                                    NO_CUSTOMER_ID   NaN
#                                                                                                                                                                    NO_CUSTOMER_ID   NaN
# ...
